# %%
import pandas as pd # pandas for data manipulation and analysis
import numpy as np # numpy is used for numerical operations
import matplotlib.pyplot as plt #matplotlib is used for data visualization
import seaborn as sns #seaborn is used for enhanced data visualization

# %%
aerofit = pd.read_csv('/content/aerofit_treadmill.csv')

# %%
aerofit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# #Datatypes of all the columns in the dataset

# %%
aerofit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# #Number of rows and columns in the dataset

# %%
aerofit.shape
# Out:
# (180, 9)

# %% [markdown]
# #Check missing values and number of missing values in the dataset

# %%
#Checking percentage of null values in every column of the data
aerofit.isnull().sum()/len(aerofit)*100
# Out:
# Product          0.0
# Age              0.0
# Gender           0.0
# Education        0.0
# MaritalStatus    0.0
# Usage            0.0
# Fitness          0.0
# Income           0.0
# Miles            0.0
# dtype: float64

# %%
aerofit.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# **Descriptive Statistics**

# %% [markdown]
# Checking the statistics for all numerical data

# %%
aerofit.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %% [markdown]
# Descriptive statistics of object datatype columns in the dataset

# %%
aerofit.describe(include = 'object').T
# Out:
#               count unique        top freq
# Product         180      3      KP281   80
# Gender          180      2       Male  104
# MaritalStatus   180      2  Partnered  107

# %% [markdown]
# Product, Gender, MaritalStatus are descrete variables and has finite number of values

# %% [markdown]
# Majority of the customers who bought the products are male

# %%
plt.figure(figsize = (6,4))
sns.countplot(x = aerofit['MaritalStatus'],legend = False, palette  = ['#f768a1','#ae017e'], width = 0.4) #'BuGn_r'
plt.show()
# Out:
# <ipython-input-44-a9805d17c0be>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = aerofit['MaritalStatus'],legend = False, palette  = ['#f768a1','#ae017e'], width = 0.4) #'BuGn_r'

# %% [markdown]
# **Insights**
# It is inferred that most of the products are bought by married people

# %% [markdown]
# **Non Graphical Analysis - Value counts and Unique Attributes**

# %% [markdown]
# **Product Column**

# %%
aerofit['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %% [markdown]
# Aerofit Produces three treadmill products KP281, KP481, KP781

# %%
#Checking the occurences of each of the product
aerofit['Product'].value_counts()/len(aerofit)*100
# Out:
# Product
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: count, dtype: float64

# %% [markdown]
# **Insights**
#
# 44% of the people prefer to use KP281, 33% of them prefer KP481, 22%  KP781

# %% [markdown]
# **Age Column**

# %%
age_count = aerofit['Age'].value_counts(normalize = True)*100
print(age_count.round(2))
# Out:
# Age
# 25    13.89
# 23    10.00
# 24     6.67
# 26     6.67
# 28     5.00
# 35     4.44
# 33     4.44
# 30     3.89
# 38     3.89
# 21     3.89
# 22     3.89
# 27     3.89
# 31     3.33
# 34     3.33
# 29     3.33
# 20     2.78
# 40     2.78
# 32     2.22
# 19     2.22
# 48     1.11
# 37     1.11
# 45     1.11
# 47     1.11
# 46     0.56
# 50     0.56
# 18     0.56
# 44     0.56
# 43     0.56
# 41     0.56
# 39     0.56
# 36     0.56
# 42     0.56
# Name: proportion, dtype: float64

# %% [markdown]
# People with 23 to 25 years tend to use Aerofit products more than the other age groups

# %%
age_count[(age_count.index>=20) & (age_count.index<=30)].sum().round(2)
# Out:
# 63.89

# %% [markdown]
# **Insights:**
#
# 64% of the aerofit product users are in the age group of 20 to 30.

# %%
plt.figure(figsize = (6,4))
sns.histplot(x = aerofit['Age'],color = '#017eae')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Majority of the products are bought by people with age group around 25

# %% [markdown]
# **Education Column**

# %%
aerofit['Education'].value_counts(normalize = True)*100
# Out:
# Education
# 16    47.222222
# 14    30.555556
# 18    12.777778
# 15     2.777778
# 13     2.777778
# 12     1.666667
# 21     1.666667
# 20     0.555556
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (6,4))
sns.histplot(x= aerofit['Education'], color = '#017eae')
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %% [markdown]
# **Insights:**
#
# 47% of the users buying the products have 16 years of education and 31% of the users have 14 years of education.
#
# It can be implied that majority of the users are within 14 to 16 years of education

# %% [markdown]
# **MaritalStatus Column**

# %%
aerofit['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
plt.figure(figsize = (6,4))
sns.countplot(x=aerofit['MaritalStatus'], color = '#017eae', width = 0.2)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# **Fitness Column**

# %%
aerofit['Fitness'].value_counts(normalize = True).round(2)*100
# Out:
# Fitness
# 3    54.0
# 5    17.0
# 2    14.0
# 4    13.0
# 1     1.0
# Name: proportion, dtype: float64

# %% [markdown]
# Aerofit has 54% of the customers with fitness level 3
# People having fitness rate 5 could also be going for jogging or running outdoors while people with fitness level 3 are the ones buying more number of fitness products.

# %%
plt.figure(figsize = (6,4))
sns.histplot(x = aerofit['Fitness'],color = '#017eae')
# Out:
# <Axes: xlabel='Fitness', ylabel='Count'>

# %% [markdown]
# **Income Column**

# %%
income_count = aerofit['Income'].value_counts(normalize = True)*100
income_count
# Out:
# Income
# 45480    7.777778
# 52302    5.000000
# 46617    4.444444
# 54576    4.444444
# 53439    4.444444
#            ...
# 65220    0.555556
# 55713    0.555556
# 68220    0.555556
# 30699    0.555556
# 95508    0.555556
# Name: proportion, Length: 62, dtype: float64

# %%
aerofit['Income'].describe().round(2)
# Out:
# count       180.00
# mean      53719.58
# std       16506.68
# min       29562.00
# 25%       44058.75
# 50%       50596.50
# 75%       58668.00
# max      104581.00
# Name: Income, dtype: float64

# %%
income_count[(income_count.index>29000) & (income_count.index<=50000)].sum().round(2)
# Out:
# 46.11

# %% [markdown]
# 46% of the aerofit's users fall under the income slab of 29k to 50k

# %% [markdown]
# Product, Gender, Marital Status, Usage, Fitness are descrete variables with finite number of datapoints

# %% [markdown]
# Age, Education, Income, Miles are continuous variables

# %% [markdown]
# # **Detect Outliers**

# %%
#Find outliers for every continuous data in the dataset
#5 metrics to determine outliers are:
#1. 25%tile
#2. 75%tile
#3. Median
#4. Upper Bound
#5. Lower Bound

# %%
# plt.figure(figsize=(15,12))
# plt.subplot(1, 2, 1)
# sns.boxplot(x='Age',data=aerofit, width = 0.2)
# plt.subplot(1, 2, 2)
# sns.boxplot(x='Education',data=aerofit, width = 0.2)
# plt.show()

# %% [markdown]
# #Outliers in Age variable

# %%
aerofit['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %% [markdown]
# It is also noticed from the descriptive Statistics that **mean**(28.0) is greater than **median**(or 50 %tile) which is 26.0. Hence there could a **possibility** **of** **outliers**

# %%
# age_25 = np.percentile(aerofit['Age'],25)
# age_50 = np.percentile(aerofit['Age'],50)
# age_75 = np.percentile(aerofit['Age'],75)
# age_IQR = age_75-age_25
# upper_limit = age_75+1.5*age_IQR
# lower_limit = age_25-1.5*age_IQR

# %%
age_25 = np.percentile(aerofit['Age'],25)
age_25
# Out:
# 24.0

# %%
age_75 = np.percentile(aerofit['Age'],75)
age_75
# Out:
# 33.0

# %%
age_IQR = age_75-age_25
age_IQR
# Out:
# 9.0

# %%
upper_limit = age_75+1.5*age_IQR
upper_limit
# Out:
# 46.5

# %%
lower_limit = age_25-1.5*age_IQR
lower_limit
# Out:
# 10.5

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Age',data=aerofit, color = '#017eae', width = 0.4)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# Users present after the upper limit that is 46 years are considered Outliers.

# %%
age_outliers_up = aerofit[aerofit['Age']>upper_limit]

# %%
no_of_age_outliers_up = len(age_outliers_up)
round(no_of_age_outliers_up/len(aerofit)*100,2)
# Out:
# 2.78

# %% [markdown]
# 2.8% of the values in the age column have outliers

# %%
np.linspace(18,50,4)
# Out:
# array([18.        , 28.66666667, 39.33333333, 50.        ])

# %%
aerofit['age group'] = pd.cut(aerofit['Age'], bins = [18, 29, 40, 50], labels = ['Young', 'Middle-aged', 'late 50s'])
aerofit['age group'].value_counts(normalize = True)
# Out:
# age group
# Young          0.625698
# Middle-aged    0.307263
# late 50s       0.067039
# Name: proportion, dtype: float64

# %% [markdown]
# 63% of the users are young between the age group of 18 to 29, 30% from middle-aged category and 7% from late 50s category

# %% [markdown]
# #Outliers in Income variable

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Income',data=aerofit, color = '#017eae', width = 0.4)
# Out:
# <Axes: xlabel='Income'>

# %%
income_25 = np.percentile(aerofit['Income'],25)
income_50 = np.percentile(aerofit['Income'],50)
income_75 = np.percentile(aerofit['Income'],75)
income_IQR = income_75-income_25
upper_limit = income_75+1.5*income_IQR
lower_limit = income_25-1.5*income_IQR

# %%
income_outliers_up = aerofit[aerofit['Income']>upper_limit]
no_of_income_outliers_up = len(income_outliers_up)
no_of_income_outliers_up
# Out:
# 19

# %%
round(no_of_income_outliers_up/len(aerofit)*100,2)
# Out:
# 10.56

# %% [markdown]
# 11% of the values in income columns has outliers.

# %% [markdown]
# **To get further insights of the Income category, the income values can be divided into 3 slabs**

# %%
aerofit['Income group'] = pd.cut(aerofit['Income'],bins = [29000, 50000, 75000, 115000], labels = ['Low', 'Medium', 'High'])
aerofit['Income group'].value_counts(normalize = True)
# Out:
# Income group
# Low       0.461111
# Medium    0.422222
# High      0.116667
# Name: proportion, dtype: float64

# %% [markdown]
# 46% of the Aerofit users fall under the low income slab ranging from 29k to 50k

# %%
plt.figure(figsize = (6,4))
sns.countplot(x = aerofit['Income group'],palette = ['#e101a3', '#ae017e', '#95016c'], width = 0.4)
# Out:
# <ipython-input-82-22f4074d9968>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = aerofit['Income group'],palette = ['#e101a3', '#ae017e', '#95016c'], width = 0.4)
# <Axes: xlabel='Income group', ylabel='count'>

# %% [markdown]
# **Outliers in Education data**

# %%
Education_25 = np.percentile(aerofit['Education'],25)
Education_50 = np.percentile(aerofit['Education'],50)
Education_75 = np.percentile(aerofit['Education'],75)
Education_IQR = Education_75-Education_25
upper_limit = Education_75+1.5*Education_IQR
lower_limit = Education_25-1.5*Education_IQR

# %%
Education_outliers_up = aerofit[aerofit['Education']>upper_limit]
no_of_Education_outliers_up = len(Education_outliers_up)
round(no_of_Education_outliers_up/len(aerofit)*100,2)
# Out:
# 2.22

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Education',data=aerofit, color = '#017eae', width = 0.4)
# Out:
# <Axes: xlabel='Education'>

# %% [markdown]
# Just 2% of the values in Education column are outliers

# %% [markdown]
# **Outliers in Miles variable**

# %%
Miles_25 = np.percentile(aerofit['Miles'],25)
Miles_50 = np.percentile(aerofit['Miles'],50)
Miles_75 = np.percentile(aerofit['Miles'],75)
Miles_IQR = Miles_75-Miles_25
upper_limit = Miles_75+1.5*Miles_IQR
lower_limit = Miles_25-1.5*Miles_IQR

# %%
Miles_outliers_up = aerofit[aerofit['Miles']>upper_limit]
no_of_Miles_outliers_up = len(Miles_outliers_up)
round(no_of_Miles_outliers_up/len(aerofit)*100,2)
# Out:
# 0.0

# %% [markdown]
# Number of Outliers in Miles variable is 13

# %% [markdown]
# 7% of the values in the miles column have outliers

# %%
plt.figure(figsize = (12,8))
plt.subplot(2, 2, 1)
sns.boxplot(x='Income',data=aerofit, width = 0.4)
plt.subplot(2, 2, 2)
sns.boxplot(x='Miles',data=aerofit, width = 0.4)
plt.tight_layout()

# %% [markdown]
# **Insights:**
#
# No outliers in Fitness category indicates that all the users have a basic awareness about Fitness and are able to categorize themselves on the fitness scale
# Outliers in the age category shows that a certain % of users are older aging around 45-50 years
# Outliers in the income data shows that around 10% of the users comparitively earn higher salaries
# Outliers in the Miles data suggests that 7% of users are interested to walk extra miles more than the average users

# %% [markdown]
# **Inferences:**
#
# From the Income slabs, it can be inferred that 46% of the Treadmills are bought by users falling in the low income slab ranging between 29k and 50k

# %% [markdown]
# # Remove or clip the data between 5%tile and 95%tile

# %%
Miles_5 = np.percentile(aerofit['Miles'],5)
Miles_95 = np.percentile(aerofit['Miles'],95)
miles_clipped = np.clip(aerofit['Miles'], Miles_5, Miles_95)
miles_clipped.len
# Out:
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
#       ...
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180
# Name: Miles, Length: 180, dtype: int64

# %%
lower_value = np.percentile(df['Age'],5)
upper_value = np.percentile(df['Age'],95)
df['Age'] = np.clip(df['Age'],lower_value,upper_value)

# %% [markdown]
# # The effect of Marital Status, Gender, Age on the products purchased

# %% [markdown]
# **Univariate analysis of Descrete Variables**

# %% [markdown]
# **Categorical Data - Product, MaritalStatus, Gender**

# %%
plt.figure(figsize = (12,8))
plt.subplot(2,2,1)
sns.countplot(x = 'Product', hue = 'Product', data = aerofit, palette = ['#7a0177','#ae017e', '#dd3497'], width = 0.4)
plt.subplot(2,2,2)
plt.pie(aerofit['Product'].value_counts(), autopct='%1.1f%%',labels = aerofit['Product'].unique(), colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.suptitle('Distribution of Treadmills among Users')
plt.tight_layout()
plt.show()

# %% [markdown]
# 44.4% of the users prefer KP281 treadmill while 33.3% users prefer KP481 and 22.2% prefer KP781.
#
# It can be inferred that users with low income slab account for majority in buying KP281 and also these people fall under the age group of 18 to 29 years
#
# KP281 can be an entry level treadmill with affordable price while KP481 bought by medium income category

# %%
plt.figure(figsize = (12,8))
plt.subplot(2,2,1)
sns.countplot(x = 'Gender', data = aerofit, palette = ['#7a0177','#dd3497'],width = 0.25)
plt.subplot(2,2,2)
plt.pie(aerofit['Gender'].value_counts(), autopct='%1.1f%%',labels = aerofit['Gender'].unique(),
        colors = ['#1a8a8a', '#80bebe'])
plt.suptitle('Distribution of Gender')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-4c941477fccd>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Gender', data = aerofit, palette = ['#7a0177','#dd3497'],width = 0.25)

# %%
# plt.figure(figsize = (12,8))
# plt.subplot(2,2,1)
# sns.countplot(x = 'Gender', data = aerofit, palette = 'flare',width = 0.4)
# plt.subplot(2,2,2)
# plt.pie(aerofit['Gender'].value_counts(), autopct='%1.1f%%',labels = aerofit['Gender'].unique(),
#         colors = plt.get_cmap('flare')(np.linspace(0,1,4)))
# plt.suptitle('Distribution of Gender')
# plt.show()

# %% [markdown]
# **Insights:**
#
# 57.8% of them are male customers and 42.2% are female customers
#
# To appeal women and increase their % of buying products, it can be beneficial to collaborate with influencers in the fitness industry who already have an engaged audience interested in fitness and exercise equipment.
#
# Targeted advertisements and paid promotions can be some of the strategies to consider

# %%
plt.figure(figsize = (15,12))
plt.subplot(2,2,1)
sns.countplot(x = 'MaritalStatus', hue = 'MaritalStatus', data = aerofit, palette = ['#ae017e','#dd3497'], width = 0.25)
plt.subplot(2,2,2)
plt.pie(aerofit['MaritalStatus'].value_counts(), autopct='%1.1f%%',labels = aerofit['MaritalStatus'].unique(),
        colors = ['#1a8a8a', '#80bebe'])
plt.suptitle('Distribution of MaritalStatus')
plt.show()

# %% [markdown]
# **Insights:**
#
# Users who are married tend to buy have higher chances of buying Aerofit products as both can use the equipment conveniently
# As the users with single Marital Status account for lesser %, exciting discounts and targeting on relevant keywords can be some of the options to boost sales

# %% [markdown]
# **Distribution of Age group**

# %%
aerofit['age group'] = pd.cut(aerofit['Age'], bins = [18, 29, 40, 50], labels = ['Young', 'Middle-aged', 'late 50s'])
aerofit['age group'].value_counts(normalize = True)
# Out:
# age group
# Young          0.625698
# Middle-aged    0.307263
# late 50s       0.067039
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (12,8))

plt.subplot(2,2,1)
sns.countplot(x = aerofit['Income group'], palette = ['#7a0177','#ae017e','#dd3497'],width = 0.4)
plt.subplot(2,2,2)
# Use the index of value_counts() as labels, ensuring the same length
plt.pie(aerofit['Income group'].value_counts(), autopct='%1.1f%%',
        labels=aerofit['Income group'].value_counts().index, colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.suptitle('Distribution of Income')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-36585c458cf9>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = aerofit['Income group'], palette = ['#7a0177','#ae017e','#dd3497'],width = 0.4)

# %%
plt.figure(figsize = (15,12))
plt.subplot(2,2,1)
sns.countplot(x = 'age group', data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'], width = 0.4)
plt.subplot(2,2,2)
# Use the index of value_counts() as labels, ensuring the same length
plt.pie(aerofit['age group'].value_counts(), autopct='%1.1f%%',
        labels=aerofit['age group'].value_counts().index,
        colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.suptitle('Distribution of age group')
plt.show()
# Out:
# <ipython-input-128-56d9975611b9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'age group', data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'], width = 0.4)

# %% [markdown]
# **Insights**
#
# 62.6% of the products are bought by young age group people while 30.7% of the products are bought by middle age group people

# %%
# plt.figure(figsize = (15,10))

# plt.subplot(2,2,1)
# sns.countplot(x = aerofit['Income group'], palette = 'flare')

# plt.subplot(2,2,2)
# # Use the index of value_counts() as labels, ensuring the same length
# plt.pie(aerofit['Income group'].value_counts(), autopct='%1.1f%%',
#         labels=aerofit['Income group'].value_counts().index, colors = plt.get_cmap('flare')(np.linspace(0,1,5)))
# plt.title('Distribution of Income')

# plt.show()

# %% [markdown]
# **Recommendations**
#
# Users with low and medium income scale tend to buy more number of products while the high income group buy less number of products
#
# As treadmill KP781 is considered as an expensive product when compared to other 2, technical features and superior can be highlighed
#
# Personalized consultations and incentives can be included to reward their income slab

# %% [markdown]
# # **Numerical data**

# %% [markdown]
# **Distribution of Age feature**

# %%
plt.figure(figsize = (12,6))
plt.subplot(2,3,1)
sns.histplot(x = aerofit['Age'])
plt.subplot(2,3,2)
sns.kdeplot(x = aerofit['Age'])
plt.subplot(2,3,3)
sns.boxplot(x=aerofit['Age'])
plt.suptitle('Distribution of Age')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
# As majority of users fall in 20 to 30 age group, there is a high probability of them buying the products. Considering their income slabs, product price can be tweaked accordingly
#
# As users from 40 to 50 years are less, probability of them buying products is less. Advertisements can be targeted to create better awareness on fitness among this age category and increase the probability of them buying the products.

# %% [markdown]
# **Distribution of Income feature**

# %%
plt.figure(figsize = (12,6))
plt.subplot(2,3,1)
sns.histplot(x = aerofit['Income'])
plt.subplot(2,3,2)
sns.kdeplot(x = aerofit['Income'])
plt.subplot(2,3,3)
sns.boxplot(x=aerofit['Income'])
plt.suptitle('Distribution of Income')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
# It is inferred that most of the users who bought the products are between 40k to 60k

# %% [markdown]
# **Distribution of Education**

# %%
plt.figure(figsize= (12,6))
plt.subplot(2,3,1)
sns.histplot(x = aerofit['Education'])
plt.subplot(2,3,2)
sns.kdeplot(x = aerofit['Education'])
plt.subplot(2,3,3)
sns.boxplot(x = aerofit['Education'])
plt.title('Distribution of Education')
plt.tight_layout()
plt.show()

# %% [markdown]
# Users with 16 years of education buy more number of products then followed by users with 14 years of education

# %% [markdown]
# **Distribution of Usage**

# %%
plt.figure(figsize = (12,6))
plt.subplot(2,3,1)
sns.histplot(x = aerofit['Usage'])
plt.subplot(2,3,2)
sns.kdeplot(x = aerofit['Usage'])
plt.subplot(2,3,3)
sns.boxplot(x=aerofit['Usage'])
plt.suptitle('Distribution of Usage')
plt.tight_layout()
plt.show()

# %% [markdown]
# Majority of customers use three to four times a week with a good probability in buying products

# %% [markdown]
# **Distribution of Miles**

# %%
plt.figure(figsize = (12,6))
plt.subplot(2,3,1)
sns.histplot(x = aerofit['Miles'])
plt.subplot(2,3,2)
sns.kdeplot(x = aerofit['Miles'])
plt.subplot(2,3,3)
sns.boxplot(x=aerofit['Miles'])
plt.suptitle('Distribution of Miles')
plt.tight_layout()
plt.show()

# %% [markdown]
# People with 80 to 150 miles per week prefer to use treadmills while people going beyond 200 miles choose to walk or jog or run outdoors

# %% [markdown]
# **○ Find if there is any relationship between the continuous variables and the output
# variable in the data.
# Hint: We want you to use a scatter plot to find the relationship between
# continuous variables and output variables**

# %% [markdown]
# Continuous Variables = Age, Income, Miles, Education, Miles

# %% [markdown]
# # **Bivariate Analysis**

# %% [markdown]
# **Distribution of Gender accross treadmill**

# %%
gender_product = aerofit.groupby(['Gender', 'Product']).size().unstack().reset_index()
gender_product
# Out:
# Product  Gender  KP281  KP481  KP781
# 0        Female     40     29      7
# 1          Male     40     31     33

# %%
# gender_product_counts1 = aerofit.groupby(['Product'])['Gender'].value_counts().unstack()
# gender_product_counts1
#same result as below code

# %%
gender_product_counts = aerofit.groupby(['Product', 'Gender']).size().unstack()
gender_product_counts
# Out:
# Gender   Female  Male
# Product
# KP281        40    40
# KP481        29    31
# KP781         7    33

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'Gender', hue = 'Product', data = aerofit,palette = ['#dd3497','#ae017e', '#7a0177'],width = 0.4)
plt.suptitle('Gender distribution across Products')
plt.show()

# %% [markdown]
# Both male and female prefer to use KP281 because of cost effectiveness
#
# Even with regards to KP481, male and female users equally prefer because of its value for money comfort factor
#
# Comparitively KP781 has less female users. Could be because of its high price and lack of awareness of the benefits of advanced technical aspects

# %%
# gender_product_counts.plot(kind = 'pie', subplots = True, figsize = (15,12),
#                            autopct = '%1.1f%%',colors = plt.get_cmap('flare')(np.linspace(0,1,4)))
# plt.show()

# %%
gender_product_counts.plot(kind = 'pie', subplots = True, figsize = (15,12),
                           autopct = '%1.1f%%',colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.show()

# %% [markdown]
# On an average, percentage of users are more for KP281, KP481 products and comparitively KP781 has less number of users

# %% [markdown]
# **Distribution of Marital Status across Products**

# %%
married_product_df = aerofit.groupby(['Product'])['MaritalStatus'].value_counts().unstack()
married_product_df
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281                 48      32
# KP481                 36      24
# KP781                 23      17

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'MaritalStatus', hue = 'Product',data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'],width = 0.4)
plt.suptitle('Marital Status distribution across Products')
plt.show()

# %%
plt.figure(figsize = (8,6))
married_product_df.plot(kind = 'pie', subplots = True, figsize = (15,12), autopct = '%1.1f%%',
                         colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.suptitle('Marital Status distribution across Products')
plt.show()

# %%
age_product_df = aerofit.groupby(['age group','Product']).size().unstack()
age_product_df
# Out:
# Product      KP281  KP481  KP781
# age group
# Young           52     33     27
# Middle-aged     21     25      9
# late 50s         6      2      4

# %%
plt.figure(figsize= (12,6))
sns.countplot(x = 'age group', hue = 'Product', data = aerofit,palette = ['#dd3497','#ae017e', '#7a0177'],width = 0.4)
plt.suptitle('Age group distribution across Products')
plt.show()

# %%
age_product_df.plot(kind = 'pie', subplots = True, figsize = (20,18),
                    autopct = '%1.1f%%',colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **The effect of Income on Product purchase**

# %%
income_product_df = aerofit.groupby(['Product', 'Income group']).size().unstack()
income_product_df
# Out:
# Income group  Low  Medium  High
# Product
# KP281          48      32     0
# KP481          30      30     0
# KP781           5      14    21

# %%
plt.figure(figsize= (12,6))
sns.countplot(x = 'Income group', hue = 'Product', data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'],width = 0.6)
plt.show()

# %%
income_product_df.plot(kind = 'pie', subplots = True, figsize = (15,12),
                    autopct = '%1.1f%%',colors = ['#1a8a8a', '#4da4a4', '#80bebe'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
# We notice that users under low income slab prefer to purhcase KP281 than other treadmills as it is economical and budget friendly. Only 5 users went beyond their budget and purchased KP781 who could be on a serious note of having a strict fitness regime
#
# Users belonging to medium income slab purchased KP281, KP481 treadmills almost equally. However 14 users bought KP781, the expensive treadmill
#
# People from high income slab preferred KP281 because of advanced technical features and status quo.

# %% [markdown]
# **Effect of miles on products purchased**

# %%
columns = ['Miles', 'Education']
plt.figure(figsize=(20,10))
for i, col in enumerate(columns,1):
    plt.subplot(2,2,i)
    sns.boxplot(x = 'Product', y = col, data = aerofit, palette = ['#1a8a8a', '#4da4a4', '#80bebe'])
    plt.title(f'Effect of {col} on products purchased')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-166-a8fb24c2f819>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Product', y = col, data = aerofit, palette = ['#1a8a8a', '#4da4a4', '#80bebe'])
# <ipython-input-166-a8fb24c2f819>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Product', y = col, data = aerofit, palette = ['#1a8a8a', '#4da4a4', '#80bebe'])

# %% [markdown]
# **Insights**
#
# Customers who walked between 50 to 100 miles purchased KP281, while people who walked upto 120 miles preferred KP481. Hardcore runners who walked about 100 to 200 miles per week purchased KP781 because of its advanced features

# %% [markdown]
# **Insights:**
#
# People with 14 to 16 years of education went for KP281 and KP481 treadmills while the ones having 16 to 18 years of experience went for KP781

# %% [markdown]
# **Effect of usage and fitness levels on the products purchased**

# %%
plt.figure(figsize = (18,12))
plt.subplot(2,2,1)
sns.countplot(x = 'Usage', hue = 'Product', data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'])
plt.title('Effect of Usage on products purchased')
plt.subplot(2,2,2)
sns.countplot(x = 'Fitness', hue = 'Product', data = aerofit, palette = ['#dd3497','#ae017e', '#7a0177'])
plt.title('Effect of Fitness on products purchased')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
# Users who uses the product for 3 times a week preferred to purchase KP281 while the ones using more than 5 times a week are inclined to buying KP781

# %% [markdown]
# ## **Relation between continuous variables and output variable**

# %%
sns.scatterplot(x = 'Age', y = 'Income', hue = 'Product', data = aerofit)
plt.title('Effect of Age and Income on Product purchase')
plt.show()

# %% [markdown]
# **Insights:**
# People in middle 50s falling in high income slab have greater probability in buying expensive treadmill while the young users with less income preferred budget friendly products like KP281 and KP481

# %%
sns.scatterplot(x = 'Age', y = 'Miles', hue = 'Product', data = aerofit)
plt.title('Effect of Age and Miles on Product purchase')
plt.show()

# %%
sns.scatterplot(x = 'Age', y = 'Education', hue = 'Product', data = aerofit)
plt.title('Effect of Age and Education on Product purchase')
plt.show()

# %%
sns.scatterplot(x = 'Fitness', y = 'Usage', hue = 'Product', data = aerofit)
plt.title('Effect of Fitness and Usage on Product purchase')
plt.show()

# %% [markdown]
# **Heatmaps**

# %%
plt.figure(figsize = (10,6))
sns.heatmap(aerofit.corr(), annot=True, cmap="RdPu")
plt.show()

# %% [markdown]
# **Insights:**
#
# The heatmap visually depicts the relationships, where darker shades indicate stronger correlations.
#
# Observations
# There is a strong correlation between Usage and Miles (0.759).
# Fitness and Miles also show a strong correlation (0.786).
# Income has a moderate correlation with Age (0.513) and Education (0.626).

# %% [markdown]
# **Pairplots**

# %% [markdown]
# ***Correlation between Age and Education ***

# %%
age_education = ['Age', 'Education']
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, vars = age_education, hue = 'Product')
plt.show()

# %% [markdown]
# **Insights:**
#
# Top left plot shows the distribution of age and bottom right plot shows distribution of Education. The off-diagonal plots show the relation between Age and Education.
#
# Users who have more than 16 years of education are more inclined to opt KP281 irrespective of their age and people and with less than 16 years of education falling under the age group 20 to 35yrs prefer KP281 and the older age group prefer KP781

# %% [markdown]
# **Correlation between Age and Usage**

# %%
age_usage = ['Age', 'Usage']
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, vars = age_usage, hue = 'Product')
plt.show()

# %% [markdown]
# **Insights:**
#
# Top left plot shows the distribution of age and bottom right plot shows distribution of Usage. The off-diagonal plots show the relation between Age and Usage.
# Users in the age group 20 to 35 and use the treadmill more than 4 times a week prefer KP781, meanwhile opt for KP281 if they use the tredmill less than 3 times a week

# %% [markdown]
# **Correlation between Age and Income**

# %%
age_income = ['Income', 'Age']
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, vars = age_income, hue = 'Product')
plt.show()

# %% [markdown]
# **Insights:**
#
# Customers with high income above 75k and falling in the age group 20 to 39 yrs prefer KP781 with advanced features, while the customers with 35-35k income and belonging to both low and middle age groups prefer KP481

# %% [markdown]
# **Correlation between Fitness and Usage**

# %%
fitness_usage = ['Fitness', 'Usage']
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, vars = fitness_usage, hue = 'Product')
plt.show()

# %% [markdown]
# **Insights:**
#
# Customers who have fitness level of 4 to 5 and use 4 to 5 times a week prefer KP781 and customers with fitness level 3 to 4 and use treadmill for 2 to 4 times a week prefer KP481

# %% [markdown]
# **Correlation between Fitness, miles and usage**

# %%
fitness_miles = ['Fitness', 'Miles','Usage']
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, vars = fitness_miles, hue = 'Product')
plt.show()

# %% [markdown]
# **Insights:**
#
# Customers who have fitness level of 5 and are a hardcore runner with fitness levels 4-5 prefer KP781 as it has advanced features and customers with 2-3 fitness level, a mid level runner and use treadmill for 3 times a week prefer KP481

# %% [markdown]
# **Correlation between all the variables in the dataset**

# %%
plt.figure(figsize = (12,6))
sns.pairplot(aerofit, hue = 'Product')
plt.show()

# %% [markdown]
# **Impact of Gender on products purchased**

# %%
round(pd.crosstab(index = aerofit['Product'],columns = aerofit['Gender'], margins = True, margins_name = 'Total',normalize = True),2)
# Out:
# Gender      0     1  Total
# Product
# 0        0.22  0.22   0.44
# 1        0.16  0.17   0.33
# 2        0.04  0.18   0.22
# Total    0.42  0.58   1.00

# %% [markdown]
# **Marginal Probabilities**
#
# P(KP281) = 0.44
#
# P(KP481) = 0.33
#
# p(KP781) = 0.22
#
# p(Male) = 0.58
#
# P(Female) = 0.42
#
#
# **Conditional Probabilities**
#
# P(KP281|Male) = 0.22
#
# P(KP481|Male) = 0.17
#
# P(KP781|Male) = 0.18
#
# P(KP281|Female) = 0.22
#
# P(KP481|Female) = 0.16
#
# P(KP781|Female) = 0.04

# %% [markdown]
# **Impact of MaritalStatus on Products purchased**

# %%
round(pd.crosstab(index = aerofit['Product'],columns = aerofit['MaritalStatus'], margins = True, margins_name = 'Total',normalize = True),2)
# Out:
# MaritalStatus     0     1  Total
# Product
# 0              0.27  0.18   0.44
# 1              0.20  0.13   0.33
# 2              0.13  0.09   0.22
# Total          0.59  0.41   1.00

# %% [markdown]
# **Marginal Probabilities**
#
# P(KP281) = 0.44
#
# P(KP481) = 0.33
#
# p(KP781) = 0.22
#
# p(Partnered) = 0.59
#
# P(Single) = 0.41
#
#
# **Conditional Probabilities**
#
# P(KP281|Partnered) = 0.27
#
# P(KP481|Partnered) = 0.20
#
# P(KP781|Partnered) = 0.13
#
# P(KP281|Single) = 0.18
#
# P(KP481|Single) = 0.13
#
# P(KP781|Single) = 0.09

# %% [markdown]
# **Impact of Age group on product purchased**

# %%
round(pd.crosstab(index = aerofit['Product'],columns = aerofit['age group'], margins = True, margins_name = 'Total',normalize = True),2)
# Out:
# age group    -1     0     1     2  Total
# Product
# 0          0.01  0.29  0.12  0.03   0.44
# 1          0.00  0.18  0.14  0.01   0.33
# 2          0.00  0.15  0.05  0.02   0.22
# Total      0.01  0.62  0.31  0.07   1.00

# %% [markdown]
# **Impact of Income group in product purchased**

# %% [markdown]
# **Marginal Probabilities**
#
# P(KP281) = 0.44
#
# P(KP481) = 0.33
#
# p(KP781) = 0.22
#
# p(Young) = 0.63
#
# P(Middle aged) = 0.31
#
# P(late 50s) = 0.07
#
# **Conditional Probabilities**
#
# P(KP281|Young) = 0.29
#
# P(KP481|Young) = 0.18
#
# P(KP781|Young) = 0.15
#
# P(KP281|Middle aged) = 0.12
#
# P(KP481|Middle aged) = 0.14
#
# P(KP781|Middle aged) = 0.05
#
# P(KP281|late 50s) = 0.03
#
# P(KP281|late 50s) = 0.01
#
# P(KP281|late 50s) = 0.02

# %%
round(pd.crosstab(index = aerofit['Product'],columns = aerofit['Income group'], margins = True, margins_name = 'Total',normalize = True),2)
# Out:
# Income group     0     1     2  Total
# Product
# 0             0.27  0.18  0.00   0.44
# 1             0.17  0.17  0.00   0.33
# 2             0.03  0.08  0.12   0.22
# Total         0.46  0.42  0.12   1.00

# %% [markdown]
# **Marginal Probabilities**
#
# P(KP281) = 0.44
#
# P(KP481) = 0.33
#
# p(KP781) = 0.22
#
# p(low) = 0.46
#
# P(Medium) = 0.42
#
# P(high) = 0.2
#
# **Conditional Probabilities**
#
# P(KP281|low) = 0.27
#
# P(KP481|low) = 0.17
#
# P(KP781|low) = 0.03
#
# P(KP281|medium) = 0.18
#
# P(KP481|medium) = 0.17
#
# P(KP781|medium) = 0.08
#
# P(KP281|high) = 0.00
#
# P(KP281|high) = 0.00
#
# P(KP281|high) = 0.12

# %% [markdown]
# # Customer Profiling

# %% [markdown]
# **Potential Buyers for KP281 Treadmill**
#
# 1. Gender : Male and Female
# 2. Marital Status : Partnered tend to buy more than singles
# 3. Age Group : Young(18-29yrs) age group buy more number of products than middle-aged or old
# 4. Income : Low income group(29-50k) buy more while High income group almost buy zero products
# 5. Education : 14 to 16 years
# 6. Fitness : 3
# 7. Usage : Users treadmill 3 times a week
# 8. Runs 60-100 miles per week

# %% [markdown]
# **Potential Buyers for KP481 Treadmill**
#
# 1. Gender : Male and Female
# 2. Marital Status : Partnered tend to buy more than singles
# 3. Age Group : Young(18-39yrs) age group buy more number of products than middle-aged or old
# 4. Income : Low income group(29-75k) buy more while High income group almost buy zero products
# 5. Education : 14 to 16 years
# 6. Fitness : 3
# 7. Usage : Users treadmill 3 times a week
# 8. Runs 80-120 miles per week

# %% [markdown]
# **Potential Buyers for KP781 Treadmill**
#
# 1. Gender : Male customers
# 2. Marital Status : Only married customers buy this product
# 3. Age Group : Young(18-39yrs) age group buy more number of products than middle-aged or old
# 4. Income : Low income group(29-75k) buy more while High income group almost buy zero products
# 5. Education : 16 to 18 years
# 6. Fitness : 5
# 7. Usage : Users treadmill 3 times a week
# 8. Runs 120-200 miles per week

# %% [markdown]
# # Insights:
#
# 1. Among the users, 44,4% prefer using the KP281 treadmill, while 33.33% use KP481 and 22.2% users favor KP781
#
# 2.  KP281 being the an entry level and most affordable treadmill is the most preferred choice among majority of customers
# 3.   KP481 is an ideal fit for mid level runners and excellent value for money
# 4. KP781 is an advanced and costlier than other options, chosen by just 22.2% of the customers
# 5. Aerofit has 57.78 male customers and 42.2% female customers
# 6. Among male customers, 38.5% prefer KP281 as an entry level and cost effective, while 29.8% prefer KP481 due to its value for money and 31.7% prefer KP781 for advanced features
# 7. Among female customers, 52.6% prefer KP281 as an entry level, 38.2% prefer KP481 due to its value for money while only 9.2% prefer KP781 due to its high cost
# 8.  Probability of female customers buying KP781 is 4% which is very low
# 9. Probability of female customers buying KP481 is 16% which is a good number
# 10. Probability of female and male customers buying KP281 is 22.2%
# 11. Married customers have a higher frequency of purchasing treadmills compared to single customers
# 12. Both married and single customers refelct that KP281 is  most purchased option being an entry level treadmill while KP781 is the least purchased one because of its high cost
# 13. The purchase frequency for both married and single customers follow the trend KP281>KP481>KP781
# 14. Most of the Aerofit customers falls under the young age group 18-29yrs
# 15. 27.78% of the middle aged 30-39 users prefer to use Aerofit Treadmills
# 16. 9.4% of the users in the old age group 40-50yrs favor purchasing treadmills
# 17. Among young customers, 46.9% prefer KP281, 29.2% prefer KP481 and 16% prefer KP781
# 18. Among middle aged customers, 44% prefer KP481 while 40% prefer KP281 and 16% prefer KP781
# 19. Among old customers, 41.2% prefer KP281, 29.4% prefer both KP481 na KP781
# 20. The probability of young customers buying KP281 is 29%, KP481 is 18% and KP781 is 15%
# 21. The probability of middle aged customers buying KP281 is 11%, KP481 is 12% and KP781 is 4%
# 22. The probability of old aged customers buying KP281 is 4%, KP481 is 12% and KP781 is 4%
# 23. The probability of old aged customers purchasing each of the treadmills is lower compared to the other age groups.
# 24. Approximately 88% of Aerofit customers belong to the low(29-50k) and medium(51-75k) income groups. Remaining 11.67% belongs to high income group(>75k)
# 25. Customers belonging to high income group prefer KP781 due to its advanced features and higher cost compared to the other two treadmills
# 26. Customers with 14-16yrs of education prefer KP281 and KP481 treadmills, while customers with 16-18 yrs of education prefer KP781.
# 27. Customers who run 60-100 miles per week prefer KP281, whil mid runners opt KP481 and hardcore runners prefer KP781
# 28. Customers who use treadmills 3 times a week prefer KP281 and KP481. However customers who use treadmills 4-5 times a week favor KP781
# 29. Customers with fitness level 3 prefer both KP281 and KP481 while customers with fitness level 5 predominantly use most advanced KP781 treadmill

# %% [markdown]
# # Recommendations:
# **Actionable Insight:**
#
# **Among the users, 44.4% prefer using KP281 treadmill while 33.3% opt for KP481 and 22.2% favor KP781.**
#
# 1. Emphasize KP281 treadmill to attract more customers because of its affordability
# 2. Highlight key features of KP281 that makes it a good entry level option for fitness enthusiasts.
# 3. Provide special offers or discounts to further entice customers looking for cost effective option
# 4. Engage with fitness communities online to showcase KP281's appeal to beginners
# 5. Reach out mid level runners and emphasize how KP481 is meeting their fitness goals and needs
# 6. Showcase the competitive pricing and outstanding features of KP481 that make it a cost effective choice for customers
# 7. Launch targeted marketing campaigns, increase awareness in KP781 among potential customers who may value its advanced features
# 8. Focus marketing efforts utlilizing various channels such as social media, fitness forums and influencer collaborations

# %% [markdown]
# **Actionable Insight:**
#
# **The probability of female customers buying KP781 is 4% which is significantly lower compared to that of male customers**
#
# Offer special incentives or vouchures or discounts exclusively for female customers interested in purchasing KP781. Limited time promotions, personalized gifts, personalized offers, package deals to make the treadmill more appealing and accessible to this customer segment. Providing target incentives can encourage more female customers to consider and invest in KP781

# %% [markdown]
# **Actionable Insight:**
#
# **The probability of female customers buying each of the treadmills compared to male customers is 42%**
#
# Offer a diverse selection of treadmill models that cater to various fitness levels and preferences

# %% [markdown]
# **Actionable Insight:**
#
# **The probability of single customers purchasing each of the treadmills is lower compared to that of married customers**
# 1. Sportsmen can be appointed as brand ambassador promoting brans's values of fitness, health and well being. Their association will inspire and motivate them to prioritize their fitness goals and consider Aerofit treadmills as a valuable addition to their fitness routines
# 2. Organize virtual fitness challenges or competitions endorsed by brand ambassadors. Prizes and recgnition for participants can further boost motivation and engagement.

# %% [markdown]
# **Actionable Insight:**
#
# **The probability of old customers purchasing each of the treadmills is lower compared to that of other age group customers**
#
# Offer personalized assistance to help the old age group select the model, provide them with the tools to maintain an active and healthy lifestyle. Aerofit expert guidance can be launched to make customers feel confident and motivated

# %% [markdown]
# **Actionable Insight:**
#
# **The probability of low income group and middle income group users preferrring KP781 is low compared to the other treadmill models because of its high price, 2500 USD**
#
# Introduce tailored discounts or seasonal discounts and incentives for customers belonging to the low and middle income groups.
# Offers such as limited time promotions, cashback rewards or bundle deals making KP781 more affordable and enticing for the target audience should be introduced
# Providing convenient EMI (Equated monthly Installment) payment options for the KP781 will be a great option to own the high end product
